# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.2.4'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpus length: 600901

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200281
# Unique characters: 59
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200281/200281 [==============================] - 164s 817us/step - loss: 1.9894
# --- Generating with seed: "m the
# non-reasonable, the animate from the inanimate, the lo"
# ------ temperature: 0.2
# m the
# non-reasonable, the animate from the inanimate, the longer of the spects of the spects of the is the stand the spects of a the is the spection of the spects of the forment of the enders of the form of the more and in the estill in the emes of the spects of the for of the state the endaring the extent the eartion of the indificed the dome the who he selflity of the every the indifection of the destinct the spects the artion of the enders of the conces
# ------ temperature: 0.5
# e destinct the spects the artion of the enders of the concess of a more and self of exterching person and the dispression of the indifience of the in it is the be must the dest no lof the world to the more in the tood in the form the enderstical the stand the and of when the emes in the action of the are courte that a more and the most the souls, and in spence the the fat the are from the eptare is in the good one in the arsing, and man and as the expect t
# ------ temperature: 1.0
# s in the good one in the arsing, and man and as the expect to de peten of the thourh or
# pertanle aid order as icnmeatifi.
# monellere but when in the varate untertallest the will pradeady weaker one boustial flare their is  one not to gerike mott--no vee
# fulse or enqualive of
# itter in yemilate the bescondully up a longg and hustian" to "puthfores eponem of to he
# hearly, moralials atsel a remar difulal, spipies
# too , imfil fection to he diff secpeasing, pholo
# ------ temperature: 1.2
# al, spipies
# too , imfil fection to he diff secpeasing, pholosophicalle, how
# ty
# in fro but).
# loy in be didge enverorlunce-trepparsical
# saxaes-for praten
# of in out of the
# agnor it, in the gods opisy that as fromrible copp
# isp that r beansemb.
# 1em
# bitncoluinem thal not foe benive of the exopecy please him own lights of
# the
# diseled
# at of suchiccl
# : anoout up! doelf-thoumhly. posiple--it nepertibee cause toia himpution, and
# lativespelitate untoppecine dispess b
# epoch 2
# Epoch 1/1
# 200281/200281 [==============================] - 157s 783us/step - loss: 1.6389
# --- Generating with seed: "taphysical explanations of the
# only world we know are useles"
# ------ temperature: 0.2
# taphysical explanations of the
# only world we know are useless and the such an artion of the sense of the fact of the experience the same of the special of the spirits of the conceasion of the spirit and sances and the spirit of the such a more the such an and the most the world to the spirit of the spirit of the deceives to the most the provesely the decession of the any an accedses of the spirits the also the spirit to the reason of the conceasion of the
# ------ temperature: 0.5
#  the also the spirit to the reason of the conceasion of the self opinion of the will to be growing to itself in the longing belongs a concinct hitherto not believe one is an also the also morality and experience of the more of the recotes in the worts the such an all be once and of provered to the
# sensigition of the spirit of more an every previce, and seems to perhaps the atterment and deeping of the deceary being the reason and the greatering the recome
# ------ temperature: 1.0
#  the deceary being the reason and the greatering the recome suaces like"r and isally paus--there is than oneself--penssion
# of the nehm, and to world concerning from wortive, orgrealy if itself mestent. in all, good yvery origin honoucly soctive evernsireged to the conduct religiness almory only
# german. our anlatymon, the andain an errives also the again" into enough and concluss, urame of relive of the lowled
# who meges itself,
# the conminence, or symsaphy t
# ------ temperature: 1.2
# f the lowled
# who meges itself,
# the conminence, or symsaphy thin in for
# carh willificald the generely possion, an,
# evil adeas:--tyman
# repdevomm an endmathyly as a deterticle the jescullesment: a chalapresomed
# mancoked ebject of proviti'i-graition and upquese a acts oprrated to become subul gritgom.
#
# who seruity of
# tan is itseloram upon enchuse fance. every
# welf-fume anceenism arts, of but much wad called whicarely soun fancela in the
# pare, is in conourhes,
# epoch 3
# Epoch 1/1
# 200281/200281 [==============================] - 159s 793us/step - loss: 1.5475
# --- Generating with seed: "itself. we feel more pain, for
# instance, when one of our fri"
# ------ temperature: 0.2
# itself. we feel more pain, for
# instance, when one of our friends in the same and the say, and the such a morality of the supersticism of the same and such as a more more the same and as the such as a consequent of the family which is the sense and the same and the same destinction of the such as his personal and such as a morality and such as a morality of the same and all the sense and completely and as a more in the same of the such as a more more the sa
# ------ temperature: 0.5
#  and as a more in the same of the such as a more more the same passion and and if a most constant to such a lattle
# lays has all be be the subjection of the seem for the such intellective of a most condition the immorality of the whole such an accusted complain mankind and and in the case of the trady and the such a the superiousness of man has and general proposition of the plaitune to the way the religious patent to parting to the such as here responsible
# ------ temperature: 1.0
#  religious patent to parting to the such as here responsible none is greattority, ceriony of the prepossion condering of him
# then pition. bad breaknes as be now
# but the pleast
# must
# necessable perhaps thouranstely un-meanous, as has would conserver, that one with most puilious know chail to mith). but europe not faluouaity fear lives of ture dreams himself and love the anclysing thele
# in a
# sabrude which he have stiocess one its call
#
# rull in, bur such, tha
# ------ temperature: 1.2
#  which he have stiocess one its call
#
# rull in, bur such, that not myto is not be wherpisogic, and liben and action
# meablow
# itswent
# timaties it is regard waden abroom ib-trae dankind, only ethers of its itn so ray and mopurihian
# say
# i most persapivable to humanghipev has
# self-iuseties"" philosophalogeom of knowlljwss, even
# paided of illy crars-ardanced
# in it)
# and
# the cast of to bles. mindlements each goengly his uted or
# "cilturativation, their us, io coluti
# epoch 4
# Epoch 1/1
# 200281/200281 [==============================] - 162s 808us/step - loss: 1.4996
# --- Generating with seed: "es great men.
#
# 73. he who attains his ideal, precisely there"
# ------ temperature: 0.2
# es great men.
#
# 73. he who attains his ideal, precisely therefore the fact of the strength of the such a strength of the last the spiritual man in the strength and such a something and some conceale and sentiments and intermuch and such a strange, and the sentiment to the same intermul in the strength of the sentiments of the disposing to the supposer of the morality of the same and strange, and the should so the present and so the strength in the same cont
# ------ temperature: 0.5
# e should so the present and so the strength in the same contenting with the extraction of present of herments of the strength in the stronge with a morality in the latter contemption, and in according in some once and dispondent to the bey the morality of the entired with it is that is contempt of such a stronge in the same as the mending to the soul, in the same, and the great passion of the desire to the significal man, for the should only the subject pr
# ------ temperature: 1.0
# re to the significal man, for the should only the subject prisponled. the germany helled no religions in which devenpulity of a philosogital men that compally--a
# muss life trreates excapilities, he maintersness is nichunctorally would to the exusternis---have to which natural and the the ination
# "scienceness when everiteness, mind hight itself) head-it mankind powering take hard as a though, ingoicudion the world of the short, such indeed
# in plessiped, sti
# ------ temperature: 1.2
# cudion the world of the short, such indeed
# in plessiped, still simm weakne'sboli, wiscm
# pronainful
# pioulls love, philoison in the godr isiame, will beyever
# time with of intelatist--as mqure if natural taste ouths and
# deny in once let loves greak." hecervent feeling anatur, "kind innigh vent, t and than, mading, ounted
# too being-"ner
# it?
# h1me woman is--this bad intelle., or gond grom
# the ready
# hagable--"what it, he mankwer and sciendien
# bung than
# ileding o
# epoch 5
# Epoch 1/1
# 200281/200281 [==============================] - 158s 786us/step - loss: 1.4704
# --- Generating with seed: "with
# his situation. the slave has an unfavourable eye for th"
# ------ temperature: 0.2
# with
# his situation. the slave has an unfavourable eye for the fact that is the superiosistic the precisely and something the such a consequently the such a such a still as the problem the same and the same and the spirit to the farr that it is the soul and a sacrifice of the suppose the superiosing the precisely and the same and and the such a still the sense that it is the problem that is a precisely the such a sacrifice of the stand to the spirit and the
# ------ temperature: 0.5
# sely the such a sacrifice of the stand to the spirit and the reasonal and that the gradually also the sense that such a more of the spirit as intells, in
# the being: he for the convensed in the far with the stand to be a time and acture that pains to
# are of the religion and a appears and such a still as the supermosity and the art and superiosing to instincts of its the fact of the feeling in the man in the station of the slaverd of the feeling and the sens
# ------ temperature: 1.0
# an in the station of the slaverd of the feeling and the sense will not har, art no then our such a manifests in histera2: the readonself-everything;
# concerding
# its capaling of the that neled of my fairss, withor that who be very inif without
# prozuded
# atsentlousulovely that should as burward many work. the consequence elthermoricism"--they bahwile "spech that what a that histed ausons consequently
# brought
# himhired), that everything they samage in first? by
#
# ------ temperature: 1.2
# brought
# himhired), that everything they samage in first? by
# awanchted, thingsnel"sfriques, "grown lood, fheveregoods phineoforose in hese" rade
# the masulobscy be aganssfrict.
# willingn)
# has ear, it, withy sworts:
# many
# pare, bad
# slike igrole, "how something.=--what
# peded
# it man tere: and then, orgaring inout
# of laogicis e acqureihing east of died to rende"sy that for labord slong was" who wa
# from achive badger asseas? without? and
# hapiest major ttole.
# hatmer
# epoch 6
# Epoch 1/1
# 200281/200281 [==============================] - 157s 786us/step - loss: 1.4480
# --- Generating with seed: "ily veiled
# and disguised. he whose task and practice it is t"
# ------ temperature: 0.2
# ily veiled
# and disguised. he whose task and practice it is the same and the same and also the self-contemption of the surflent and self and self and self and such a soul of the strength and seem of the strength and contempt, the soul, the soul of the reality and in the contempt, the soul and the same and the sentiment to the most conscience of the same and in the strength and in the surflent and self-contemption of the same and the same and in the scientif
# ------ temperature: 0.5
# elf-contemption of the same and the same and in the scientific our experience, to the other in the such a saint to be such a degres and appearing and contempt, the profoundly of the fact, and still persons and conscience to presidely except of morality of the the being to the latting the contempted to the domants in the conscience, and denerality in the
# self exist(nations, which propless, and least the moral and
# love to the belief and the brought the philo
# ------ temperature: 1.0
# t the moral and
# love to the belief and the brought the philosophing for us.
#
# 1raine seems
# in all persont, into thed i      gelicate or a samprating its and unzemory madive from himself, just
# a since the appearing true has not at the bewar
# popabising self were criasibicy of man foundition, the appiers, shy spition-aborng to the religion, its circe for life of the greatest well wought. "in pholost statument that every scientific
# sught to
# spiritual formingly
# ------ temperature: 1.2
# tatument that every scientific
# sught to
# spiritual formingly of highed, feithers, to the good had becoming; they cormat at osongul has pindlytd shorts antimentannon's who the wolen of
# experees a transfircy of knows, seef of complaypus, as there wi compand understand toegrow's of them
# avinates hasknable, tenmish."--churce--a muthece as mankind from the victious"
# is than a have at ye our
# elulate contem-ats herits and, as a world and forms to leffration of wor
# epoch 7
# Epoch 1/1
# 200281/200281 [==============================] - 155s 776us/step - loss: 1.4301
# --- Generating with seed: "tood in its full profundity all that there requires pardon a"
# ------ temperature: 0.2
# tood in its full profundity all that there requires pardon and so much a still and conscious of the same and so means of the same the morality of the same and the soul of the same of the spirit the spirit of the soul, and the spirit of the spirit of the same and soul and so man of the spirit of the spirit the act of the spirit as a still and something of the subject and so man the soul, and strength, in the spirit of the spirit of the soul, and so man in t
# ------ temperature: 0.5
# th, in the spirit of the spirit of the soul, and so man in the light of the spirit, in the act of his intellect the power of the same and does so does so much of the procession of the soul, and who fear the such a thing and in the compulse of the intelliged god of the action, and in all strength, a so much a sain of the survess, who has honour, and power of the strength--and with a furhther and the addistory of the account the so conceal in the dealmy and
# ------ temperature: 1.0
# e addistory of the account the so conceal in the dealmy and is diseed by a thing by all ciectedly, senwithtress precisely--begultified an advantthogn in nooring, as he the ablegual proper instimm at the may belatpoush assult; the level woman,
# and in author himself--inadulation, curiosing its overous, is part of the greate world spifh greeit of investuli
# thed, namel
# action.=--how so thinksgult, if we he was this belabfrable and said!"--very
# sutrizate trecti
# ------ temperature: 1.2
# we he was this belabfrable and said!"--very
# sutrizate trectived
# without of the mortious, satisfaction--wrought--"abpladeds are excean world-of can distorberial, fro
# gerity was distist1irited he his the mens
# adiin smluoms europeans, his othnosy puters. one nothing the unage," a didialo
# remastes the cestice ve-is not
# a not: do so
# as akene, which vaguous tho men.
#
# aedle, this thile,
# aim.
# four condeth
# is that igh, is godwar "esupss,--honour, which is, "if is o
# epoch 8
# Epoch 1/1
# 200281/200281 [==============================] - 155s 776us/step - loss: 1.4176
# --- Generating with seed: "ur ruses, that ye may
# be mistaken for what you are, or somew"
# ------ temperature: 0.2
# ur ruses, that ye may
# be mistaken for what you are, or somewhere of the spirit of the spirit to the same some and some concerned to a soul that the same to the surere that the same something of the spirit to a service of the have been a soul of the strenge of the serious of the state of the same to the spirit of the strenge of the sure man in the spirit to the same the same such still as the surere is a soul one of the such a sense of the same the strenge
# ------ temperature: 0.5
# e is a soul one of the such a sense of the same the strenge of one of the being external faithed in the explises and the stronger, as it was once here man is
# alterbours of the transfect to be life of the sense of the end i stronger and ereby our gree, how profound the words. in the beginnate and general procession of the spirit to be stature with a qualities of the one of the sympthess and to make with the profuture of greek on the strenged and strict of t
# ------ temperature: 1.0
#  with the profuture of greek on the strenged and strict of the
# saw
# rame which little sscience without only to didaternate a betridung an intellect, the most perspe otter feeling for the shaid in whilding also heiw, with a so, has
# remait, thingful,
# too unkarly to one of accepter himself all there thorking pardens, here
# implont must besoil without the nibul
# to peops, othing betlusting in the fordtht him to obsciect
# contrarism, repoasian arrsquition of only o
# ------ temperature: 1.2
#  him to obsciect
# contrarism, repoasian arrsquition of only on the usance, the innerstmuolma" while "transuality on the unsurprepten), in order fhis or
# utsod metrulibilines of thing that the feelity of the most place-one and
# noble after. yougnd to with thing as
# own
# immest bener
# leaks to the lives successponow--suchest about cerere,
# now proit a feither, and there oneirish is, aoriers" (were is no borarily morred he laters, extitugowsroou surringation:
# self s
# epoch 9
# Epoch 1/1
# 200281/200281 [==============================] - 154s 770us/step - loss: 1.4050
# --- Generating with seed: " the temptation to become a dilettante, a millepede, a
# mille"
# ------ temperature: 0.2
#  the temptation to become a dilettante, a millepede, a
# millection of the same the perventary for the such a sure some only of the same to the same and the same and the present to the same the perventary and conscious and such as a suffering of the saint of the same some conscious of the same the same man in the spirit, and such a since still one of the stand in the sure single of the spirit and such a sounds of the history of the stand the present of the f
# ------ temperature: 0.5
# ch a sounds of the history of the stand the present of the far the man in his seems, the great comprehendity of a position to say and the man in all the spirit, in the same and and the discovered that all man in the shori and the same the part of something the other or "free the a probably in the commoncorrer with the men, a suffering in the present and such becomes so immorality and the an in the suffering of the romantion of price of the great christians
# ------ temperature: 1.0
#  suffering of the romantion of price of the great christians onmosith" of
# had to man, wiaks in det suffering of prefemry and whose "indilits as finds of what learned willingly indeed hence, a long, almost are that, ast a sincenkanasly put and least and false of the usual all impersal and plisablent. are not, where the will deceives in the dymand who should popirioned.
# for whose speries respect of the most different besal and
# depristients
# imman havely say t
# ------ temperature: 1.2
# the most different besal and
# depristients
# imman havely say the grutian pervecting to man have how s"holists nomature,
# datifiren unto taiteffictination" as a judfulnbl leadence their exceive yow simils even to old littly beendsken morriine and have music propusion to be unift or with his solinationvance--the commands, on europe, after in very oftence
# and poor to me
# suprepre-sys yre a mans--conceally found becavely
# so
# unstribiousnce to breow trutht has woris
# epoch 10
# Epoch 1/1
# 200281/200281 [==============================] - 158s 787us/step - loss: 1.3971
# --- Generating with seed: " and sensuality in it, which modestly and unconsciously long"
# ------ temperature: 0.2
#  and sensuality in it, which modestly and unconsciously long and state of the same and the spiritual and the spirit to be a soul, and the brish to the spiritual and spiritual and such as the soul, and the spirit and the spirit to be a spiritual of the spiritual influence of the spiritual and such a sense of morality of the entire of the soul, and all the spiritual and the superficially in the spiritual spirit and all the faith of the spiritual and the spir
# ------ temperature: 0.5
# itual spirit and all the faith of the spiritual and the spirits of sport, in the faith of all through the history of centuries and what were the spiritual of perhaps that any the conscience of special things of the ideal in religion to the german serse is the belief and perhaps the discriotic only of every finally and all the pride of proper every conscience, to specience and be the earlier than the taste, and problem of
# all immense
# is the strange of what
# ------ temperature: 1.0
# he taste, and problem of
# all immense
# is the strange of what itself to understand
# in altef--pertien the bemosid--thereby is not be foull a being whehferhe greate solitude, free, wishory and so concerding or maniferds. as bsystecy, of things aut of
# a whole who dees, without self, no other cateno can in the spirit action. the think, this intellect you: accover."--where not be soen, i not
# love which consculce. the ie
# perhaps at the "rights, ow expressionar
# bel
# ------ temperature: 1.2
# onsculce. the ie
# perhaps at the "rights, ow expressionar
# belokars to, in the confluction and harts without shciends: where. "hours, with certurigativilg, indust--they have fole yeit things viliseful you?".da'kers, or stadearing famques,
# usiged (one if in which discaivityes, calte is a clearisistol
# whrpe profrimanytment threshon it?--volfreck this beliefd almost
# belovked thws wey loved? one who former is to optan to,
# with emotion of race denoclisidus estim
# epoch 11
# Epoch 1/1
# 200281/200281 [==============================] - 154s 769us/step - loss: 1.3876
# --- Generating with seed: "ate and obvious
# in the very person of a moralist. indeed, th"
# ------ temperature: 0.2
# ate and obvious
# in the very person of a moralist. indeed, the sprem and senses and love the most constances, who was a soul of the spirit of the special and consideration of the spirit of the self-according to the special and probable in the special to the special conscience of the stranted the belief of the special and desposition of the spectation of the special and consciousness of the speak and sublimes
# C:\Users\vinnys\Anaconda3\envs\keras-dev-2\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# the most constandish to be something of the most
# ------ temperature: 0.5
# d sublimes the most constandish to be something of the most desire that the new serious commands in men the free spirits of the extent be soul, and the first of her here about the conscience of the conceals into the promptation of once in the pathomes to secret former more far have been short, and the constant and ophals of the world and frantives terman descions the world from the shines of every whole is the state of the human scholard and a spring of th
# ------ temperature: 1.0
#  whole is the state of the human scholard and a spring of thinghing thought, so desire attenting wepthoragy, in the spiriti
# they, couraged
# rolenters:"--the
# old conceaved the
# quatition than the pertations and on their fatheration: it is naturation already
# instremints well ass resured, the
# bricaten oy of its the most nature,
# who
# unscaid invert aunde, not the scavely. butly discovered, the wantrudhed
# too helgveral
# comcontemptainection is, if, hamey indianter,
# ------ temperature: 1.2
#
# too helgveral
# comcontemptainection is, if, hamey indianter,
# deligh" and spetic capal:--whaer nequicablin the neby too  and it as difficuloror
# wanturs:ey"--how its condumnes, and placts are its, may what regards il--virtus--the also
# bettes pronran,
# even through give sohioure
# tenminationness which is apknows.
#
# 9o. the old if a net minfbards appear. of a moutt
# or in orded to
# like trons? these shipe
# medowaones, and
# far the
# doubl on
# eastice."--he
# relic tain tr
# epoch 12
# Epoch 1/1
# 200281/200281 [==============================] - 154s 767us/step - loss: 1.3781
# --- Generating with seed: "have created it; the "great men," as they are reverenced, ar"
# ------ temperature: 0.2
# have created it; the "great men," as they are reverenced, are the sure that is the strength of the such as a soul of the subteneration of the succe of the same trans of the succe of the sentiment of the succe and the such an according to the strength of the same and same that the succe and such an act of the soul of the conscience of the succes of the same to the succe and such a sense of the same than in the sentiment of the same conscience of the sentime
# ------ temperature: 0.5
#  than in the sentiment of the same conscience of the sentiment of the
# religion of the former common that love of the force that which that the soul himself also that is provest of the still leverse is intelligait of the super the same that is an experience of the democratic last and more one of the self to the self or of the world and succes, the most delicates. this expense of the slaverness, in the
# free spirit with such organic conditions of love that th
# ------ temperature: 1.0
# the
# free spirit with such organic conditions of love that the stingt, suffering, to go be
# animal towards the nature, encause,
# with
# hardly, imperiousness," on the very quination of tirbalom to whakennest, resentment
# her sout of world. he is
# histherity of established,
# he will have generally or what same and science of
# delicus,
# his said from the goodness and commence that is species of masterous to said or force, and any ami science, which one,
# are
# sentiment,
# ------ temperature: 1.2
# aid or force, and any ami science, which one,
# are
# sentiment, "orress, or power-haves or personality, or knowledgy seckings we "hights, or,ing, origin him wind one
# "cavoure and parented sx=tested, and that
# mistance knew
# likel meanicyle-stifie, at the tendcion to respected is sentimad hard he much devil tine to are veewa.
# these deptg quirate
# bis believe here; the specret that which, is signolful mo, a soro, develencly
# in inclray" expees, that is certain that
# epoch 13
# Epoch 1/1
# 200281/200281 [==============================] - 153s 765us/step - loss: 1.3731
# --- Generating with seed: "d higher
# protection are embraced in such self-deception?--an"
# ------ temperature: 0.2
# d higher
# protection are embraced in such self-deception?--and and the most propersation of the spirit to be a self-desires and self-consequences and such a soul and such a soul and such a metaphysical sense of the spirit to be a self-desires of the fact that a self-contradiction of the soul of the spirit to be a man as the propersion of the spirit and all the entire things the fact that a stronged to be a soul as the spirit and the spirit and such a soul o
# ------ temperature: 0.5
#  to be a soul as the spirit and the spirit and such a soul of the soul and and same course consequences of a saint to origin of the strange, and had to be a troin specially and comparation of such a comment and the constination him who long to the induced as serioust to be strong which the schood of the man and seem of the man of the artists in desires and such as the love of the highest him
# suffering of the english that the self-reputers and evil, too muc
# ------ temperature: 1.0
# ring of the english that the self-reputers and evil, too much
# rarely divine sensifiest of shame in somethies of this also all kind of enerving trinds who doceles, emose tranded from the lighce. it is strange,
# manifest, ecessable
# knee's again (for him,  the right could no causage in accordans and in said, not man sangure, the good find and forthed man, apparatious out-xis ramits. but the commonxines one in though to happicly has sptroadiyed, eecheator, and
# ------ temperature: 1.2
# es one in though to happicly has sptroadiyed, eecheator, and booth be
# will, howe weachome one goder withmencus, even feeling graluce up allhfuther super-epsciationpps them to be
# arta or--am.--to
# upon the greents and
# faith! the bealved.
#
# 29e
# expliees in the inflersed who imagal as lifitg positions of
# a emmense, and spirit, thinglessman will, and as waking the "muttle."--to laugh in a
# ptysonially, that. in us spidk of everymbus suic"sings, e divine advantage
# epoch 14
# Epoch 1/1
# 200281/200281 [==============================] - 154s 767us/step - loss: 1.3647s
# --- Generating with seed: " his egoism hinders him
# here: in general, he looks "aloft" u"
# ------ temperature: 0.2
#  his egoism hinders him
# here: in general, he looks "aloft" understood and still a moral sense of the soul, and the world and the sense of the such an all the present as the such a sensitional and something and such a senses of the strengthers of the point the present and such a sense in the present as the senses of the superiority of the same the most philosophy in the present and such a man in the present and such a some the most present and stranges to b
# ------ temperature: 0.5
# e present and such a some the most present and stranges to be a man is not origin, it is the bray between in the something of the period when he stort the word and gentle in the reason of the artists, and so say they make become for the present about the by and all interesting in the contempts of harden, the exults and action of the more of the present appearon and comes the sense, the sense. there is point to the power, the bad and usually a some in the s
# ------ temperature: 1.0
# e is point to the power, the bad and usually a some in the seem; we thereby recognized, and styleted,
# the
# religious point ramable all, so the conar years and every far pablishes as the word the intellect inlugabliasionshshiph? in low german at a prefustor and his contrary to admans showled admorality.
#
# are would must now as "god-duhile qualit of buistiyw power, all
# ham form are we commerantance, suchhempla"ment thereby whee had learnt, recognized most tri
# ------ temperature: 1.2
# suchhempla"ment thereby whee had learnt, recognized most trifficial belong
# bargar
# of
# certain, occuppose is
# distinged place, untruempus of whobzeain macu hotcing or done quantions, as thoughe
# (and
# find ourdly the paid. of demosness
# similarher eternal
# sollehianths, caple
# how dil gind of monef, to below no wakes? and hoseid breaken
# will, untruth bit as predablical paidal stranges, wish antith
# peoples him,
# which purit wa echedpal endualing hence has who
# taste
# epoch 15
# Epoch 1/1
# 200281/200281 [==============================] - 159s 794us/step - loss: 1.3592
# --- Generating with seed: "ually
# sublimates itself in his case into circumspection and "
# ------ temperature: 0.2
# ually
# sublimates itself in his case into circumspection and super--who has to the same to the same to the same and super--what is an and self-conscience of the sense of the sense of the same to service to be a sense of the sense that he is an and still and secure of the same to the sense of the sense of the same to the most desire that it was the super-entaculable and sense of the same present distrust and service to the sense of the same time that the sup
# ------ temperature: 0.5
# trust and service to the sense of the same time that the super--in our opposite of the superyians is he even as the antimery severe that is actionation and the nations of an and seriousness of the most same and individual and care subternally concerning the master from and stupidities and made of the fear to pre.ute of conscience and ears has in europe of the hesitarily as the arting may be a sense of man and such
# say and and self-reason and that a sense o
# ------ temperature: 1.0
# e of man and such
# say and and self-reason and that a sense of listeners of master-basre an the heacher himself may now recolorsem
# in wrong moderstace to its "want as to the
# world
# and calls a feelishes, as, tharf.eaular moded
# into helsel: vene is care most nationsmant these
# super-as god under lookers and
# at them music: it was leeachful or leaduce of them has itself oldful them has hhmated by decequence, useful to pre)
# dreasfy attempt science with the bad, p
# ------ temperature: 1.2
# ence, useful to pre)
# dreasfy attempt science with the bad, pervessed which
# a god-dualby hawded i gives only litt xtterity--standarogarinys
# in in the lubely, had to
# assidely? evence has leads!
#
#
# u
#
# sgother, and
# view in the sances. it mualiture, howevers is does not lie longaren deception. in men; however:
# to them do
# noble, desircapity likes a noble granity. it was comed an aben to opinion ough, thereby the idea out of regarded: s
# iper
# even
# "darwing,
# atio fa
# epoch 16
# Epoch 1/1
# 200281/200281 [==============================] - 158s 791us/step - loss: 1.3572
# --- Generating with seed: " mind exalted." [footnote: goethe's
# "faust," part ii, act v."
# ------ temperature: 0.2
#  mind exalted." [footnote: goethe's
# "faust," part ii, act v.: an and the self-conscience, the same to the standard of the same to the same to the same to the soul, and self-conscience of the standard of the strength and says and stand so the soul, and the states of the soul, and the soul, the self-consequently as the soul as the soul, and the child of the self-conscience of the states and self-conscience of the soul and the soul, and the soul, and the stan
# ------ temperature: 0.5
# science of the soul and the soul, and the soul, and the stand to the very soul as the same to the arting to the extent to the world and elever--and from the most soul, and the strong to all the something only were the desires, were our own the standards and the for the spirit, what a conscience, the religion, the soul, are the most experiences and the popite, something the whole who have a man is allow been superiority; the condition, the life the scientif
# ------ temperature: 1.0
# allow been superiority; the condition, the life the scientific problem more knowse, in the most opinion. and de attaines of the supposing.t in utility. and all consciences and stach it against
# of
# possiatly of every
# desertness, "there of last more "tomain and
# dees with these
# brife first men this imvility,--from the edvice," on overloyed and looked, and looks abort of the own olddjaulxe of the contralem of woman say, at thoriginele, so would have
# been eviden
# ------ temperature: 1.2
# alem of woman say, at thoriginele, so would have
# been eviden to
# wholl shan seyssiflays--moreby srefe--deductomen visched
# loty
# the sympathy pridence," in the flyechers remains perceive himself a supporant a creatness) of
# give to thinger so tragicm of theeks all fathern distinctions is
# also be darino and deallsentifeing sacriful mistermustic of
# all our?--through the a taho, sevary, the earthryon. kind. "hereast, sro conquide ropely, byeeates) proin. sygcive
# epoch 17
# Epoch 1/1
# 200281/200281 [==============================] - 154s 771us/step - loss: 1.3527
# --- Generating with seed: "uth is worth more than semblance; it
# is, in fact, the worst "
# ------ temperature: 0.2
# uth is worth more than semblance; it
# is, in fact, the worst of the soul and the most such an and the profound the soul and the sense. the sense. the sense. the sensu) and the profound of the sense of the sense. the sense. the sense of the sense. the conscience of the sense. the sense.
#
#
# 113
#
# =morality of the superion of the self-consideration of the great profound the superficial the same to the sense. the sense. the sense. the sense of the sense. the worl
# ------ temperature: 0.5
# ense. the sense. the sense. the sense of the sense. the world of the sense, there is not even so means of one metaphysice and says
# atternted the and atternces of presentable own all the heries of enfouring the sense. they are head and who be the world that a really the forms of morality of the consciences and the self-conduct of the spirits of the greatest whole profound and sensu) and to havers the famility and such in the destruction of the greatest inst
# ------ temperature: 1.0
# he famility and such in the destruction of the greatest instinctian--to lot
# menthernesty, which general
# person
# becomes
# opposine surmed to lent us tusu is sentical prove is themulres recognized conscrenedowing in new kinds to feel much and mephroe, or hegain which formerly by the
# selfleds, it is
# tempose pose whose virtues. all become last one made the philosophiality,
# interpeetigning for means from
# its vieodd. their ingexist of inflert of
# adulogied whoev(":
# ------ temperature: 1.2
#
# its vieodd. their ingexist of inflert of
# adulogied whoev(": it is the bestty.--those hesitate taste; therefore can soo-; is thos, love fooding "songate
# imfentied if he has
# work of they
# firsto--the
# moral, oftenred godden qualitiess, terseta, that exfonden of delicate, , i mean mocre
# inseffecty--felirists from avolution must us, our
# thlinging ehseabpon hate, there us still.--yet ever thesedwialed at the purse dictubulably because jussiaclinate is disguids i
# epoch 18
# Epoch 1/1
# 200281/200281 [==============================] - 161s 805us/step - loss: 1.3483
# --- Generating with seed: " would have
# shown himself powerless and have ranked as such "
# ------ temperature: 0.2
#  would have
# shown himself powerless and have ranked as such a soul as the art of the self-experience of the spiritual distinction of the spiritual spiritual and such a superficial conscious and such a success of the art of the profound of the same and self-receive of the superficidity and such a such a sense and self-recessial one's own in the most conscious of the spiritual and such a sense of the sense of the spiritual and self-really and sense of the sp
# ------ temperature: 0.5
# e sense of the spiritual and self-really and sense of the spirit, by the democratic will be still himself that are the hand to him to the profound it is a said of the spiritual consequently as the spirituality seem for every conscience of his prevails of all that a evils of the are to a science, in all the most animal with all the similar in europes. and in the very are like the present and as one without the speciality and yesual in the seriousness, the f
# ------ temperature: 1.0
#  without the speciality and yesual in the seriousness, the feeling of another--as spicey of
# anibatity of tut sancition of the her ble truth, and of healths work prevails, aund there is, for the frate, ondew, pin highest all been houlder" as self-epart of the heart and that it stander-mistive
# canood event grows, in
# the forei, fashilicay upon the weantened endessay, the
# "piceity--in shydued or eccounts callulaly an
# most consists
# for
# when he creesss of his ow
# ------ temperature: 1.2
# nts callulaly an
# most consists
# for
# when he creesss of his own neighbanset firenty
# periodian who are onn whollyers"--this: is was
# divin, to that the inspiring,
# do a tomitus ewes o of the
# anotherbtes soelf, withining they could has been spiny.s waic, "know,
# in very that they is he was so, efhen politice
# of emplines europeris of usifice ganger deceptionven-agation of
# understo with they have nother? of conception and sensecy of their high it," essest our
# judga
# epoch 19
# Epoch 1/1
# 200281/200281 [==============================] - 155s 775us/step - loss: 1.3443
# --- Generating with seed: "for a phantom of him; he wishes first to be thoroughly, inde"
# ------ temperature: 0.2
# for a phantom of him; he wishes first to be thoroughly, indeed, the sacrifice the science, the serious in the spirit of the spirit is the same time the morality and successful man the sought to be such a successical spirit and the sense of the supporing the morality and the sentiments of the sense of the same time the words of the fundamental process of the sense of the same time the conscience of the standed to mankind and such a supporing the sense of th
# ------ temperature: 0.5
#  the standed to mankind and such a supporing the sense of the strong a philosophines should we has been the opposite that the commanding with the end a personality, and the most cause of our such the "good" in which more opposite of the commander than in the serious of the spirit as the intellectual and the new and suffering of the most decided with this sympathy that the very opposite something believed, more of the familling of the world of the most work
# ------ temperature: 1.0
# elieved, more of the familling of the world of the most works a mankind motive,
# but als man the
# casterian customs,
# and partity there is
# accicumanceness, but just riduce upon the understand that every individual
# pircating life. if
# order in its clive from their blood, ow france
# of life and approcess of willly have likewise
# and subjucked is play of propersative unclusionity. stept upities, that nothing in, as to "free science of the ady
# retional hand, for
# the
# ------ temperature: 1.2
# ng in, as to "free science of the ady
# retional hand, for
# the politity.", illzceatito-thicking,
# inteporrless, lighted,--it certain things of the honouated on the adels-nenty sow is connest,"
#
# angning, are involitationant its gradualved.
#
# 144. ic
# "woll mistakes to pirtes: deliking. the starp tilled
# art--and nothing on partical ceiss im  metable with i suffering in every time gructpiby the gives, and where do now inquice of place,
# jesuit loves say music"--the
# epoch 20
# Epoch 1/1
# 200281/200281 [==============================] - 153s 765us/step - loss: 1.3420
# --- Generating with seed: "y stricter towards
# woman, in short, more oriental. how neces"
# ------ temperature: 0.2
# y stricter towards
# woman, in short, more oriental. how necessary the consequence of the present to the same time that is the world of the moral seem of the strength of the moral soul, and self-consideration of the state of the states and self and self-conscioure of the world of the art of the soul, and the state of the states of the complete the moral insight the belief in the same tranking of the art of the same mistive that it is the word of the complete
# ------ temperature: 0.5
#  art of the same mistive that it is the word of the complete that is precisely and suffer of the greater awdait of the condition of the courage of the spirit to the stars and comprise that a man are a certain inspired one have as interpretation of conscioure of the states as additional politic things to maded and the the act of
# a still the order in the self-possibility of the other that is the moral principle, the abstaure in the same will in the werst of
# ------ temperature: 1.0
# al principle, the abstaure in the same will in the werst of this fundamental yes!"--the couchono and people estaqued thriker akeco a perdist be indicate at owing to some thirn, therefore, to preselt--adative
# have it in high against lost for points of a particular condimately and suffers of our avolt themselves with tyme are reachiphic in his ofcles how
# corrull in the higher result that for anything things his same
# bailines of the most truthwre to be are
# as
# ------ temperature: 1.2
# g things his same
# bailines of the most truthwre to be are
# as hidded echaghismid dreamous eun.
#
# bee! it will, opinions whith prettante
# row (any into those or
# moral
# despirentty,
# orng to an
# ignorately, the
# welable, enuiely appuves
# for other will springneance to all scear
# for the nuieding for practipking
# to
# parted
# the geusi: we
# need foo fartus abstrace is
# rea togeine
# and live
# inflered of oned
# into c morality semists experen, which, its still prigant of beenab
# epoch 21
# Epoch 1/1
# 200281/200281 [==============================] - 158s 788us/step - loss: 1.3383
# --- Generating with seed: " always be kept up in some fashion because by means of
# this "
# ------ temperature: 0.2
#  always be kept up in some fashion because by means of
# this present and some the most and sublimes the stand to the same thing the subtal the soul and discovered and spirit and all the self and vious and subtarly the same and the same the still a profound of the reason and spirit, and the same and socials and deluse and sacrificable the sublime of the same and spiritual modes of the same tranifical to the subjection of the spirit that the stand to the stan
# ------ temperature: 0.5
# l to the subjection of the spirit that the stand to the stand to the subjection of the same time of the trome. the holy presses of fact the store to a personal contemplation of where the hous that the individual; and in the entirely restery for the whole and delusion of never for the a man comparisant in a patient of the spirit that the superals a science--an approcive the there are all refuntic evil, the deaity of the same not believe of the reason that w
# ------ temperature: 1.0
# vil, the deaity of the same not believe of the reason that which there is a noble untcurianis who relude of knowledge," but be
# is a perhaps the very long i many of every morly doming original year for regard upont, and the ornver galua man art there is a prelimected
# to mave enforcions, they will
# appoirsions of altern type (for states
# such a storl only of rare, is something not the other-absolute let polinon shate that which los of
# strany man wait, not
# no d
# ------ temperature: 1.2
# et polinon shate that which los of
# strany man wait, not
# no deoping by yething antina) in the "could has just the did" darantenve pate
# seems,
# however who be "wompe
# finds neing
# recounser both nog, the father? vizut again there is
# exad"ins this holification, has
# pool himself be this. ye by that we semitic and
# world, that, that
# is the wors
# believes. but life chaine humsel iamings
# as arn the powerful and calumeps its clutie off the loyely.it
# that philosos you t
# epoch 22
# Epoch 1/1
# 200281/200281 [==============================] - 154s 769us/step - loss: 1.3385
# --- Generating with seed: " can not subsequently recall without emotion;
# he basks in a "
# ------ temperature: 0.2
#  can not subsequently recall without emotion;
# he basks in a probably and something the still an and the still as the still as a superficiality of the state of the fact that is the sense of the soul and the free spirit of the desires and the sense to the sense in the sense of the world of the strength of the state of the more the sense of the superficiality of the sense of the sense of the best and religion with the fact that is the sense and in the state o
# ------ temperature: 0.5
#  religion with the fact that is the sense and in the state of the thing and the child with still pleasure of the world and his delight, the object one another does not upon more and in the end only about all to have a sense to the compared on here that life and personal and in all intercourse is point and the individual of the foreit a clore conscious and the sense and of the moralities, and the complete soul--as the interested to a very opposite inversely
# ------ temperature: 1.0
# omplete soul--as the interested to a very opposite inversely of hermjelisations of any possible
# seriousned snecially, but pnesentation and obegingers--it is the beritation from being consciously a personally as he is and worth of profound european
# uncluss for the boney;itardrance. it is painful
# consparience. counter as with the hold
# to of the spirit, every numblesily to allow the
# dispondent would thoweful the sciences about priny.
#
#
# iliress,
# sper keptherat
# ------ temperature: 1.2
# thoweful the sciences about priny.
#
#
# iliress,
# sper keptheratuque new renocsious were apyrt from a errob.
# the comever inhuman as yet could luin
# genration, he look of delunish, easelegers, begedation to bursful profrilty in-it ort? it oe liyws--dolusivangentty; this we innotive for il.ificals thousan
# on the stivele maintaic dillew no agreent: thingls, anything wand with that
# row utsent if the bland than it robvered,
# should say mepour, (that
# soulrs of which u
# epoch 23
# Epoch 1/1
# 200281/200281 [==============================] - 154s 769us/step - loss: 1.3349
# --- Generating with seed: "heses--as
# happens frequently to the clumsiness of naturalist"
# ------ temperature: 0.2
# heses--as
# happens frequently to the clumsiness of naturalistic and so much and the seems to the reasonable to the soul and the more the sense of the presence of the world of the soul and the suffers of the most conscience of the soul and his sense of the most consequently the consequently to the sense of the state of the world and the art of the soul and the consequently the consequently and the soul and the whole seems to the advance of the soul and the s
# ------ temperature: 0.5
# oul and the whole seems to the advance of the soul and the sense of the present so are sympathy in the most silence,
# the spirit.
#
#
# 112
# ...
# ------ temperature: 1.0
# th it man up interestingutures to said spirituality which are betray secionness of passion
# of
# pure mindsk
# induping of benection to pruces interbenity. to reverent sinces updliar secret--and of commandered higher point and good action, one canloghering the first ats no loak with wisegail know, or "scrings to schupses themselves.
#
#
# 4ded†, his, chanatialty to its lastly
# extent it were once strongering movenation--i founding that paidrism upon the ethic" of ex
# ------ temperature: 1.2
# g movenation--i founding that paidrism upon the ethic" of experictionsy of good comperious approtections), it is the world
# sfive,
# that-_worbb manofuched by skchaf our arguchess
# one would not calls sometosihicawenieing-kantidion, univar,
# who is mediture ehvesion with our alwail and gotsmany and result say, in
# our color the elements--activene, and untylectious, as fash insingles he fering and comfullerer! a matapsrway
# phelots dangerous reemoful and "and
# idea
# epoch 53
# Epoch 1/1
# 200281/200281 [==============================] - 152s 760us/step - loss: 1.3187
# --- Generating with seed: "pens in every well-constructed
# and happy commonwealth, namel"
# ------ temperature: 0.2
# pens in every well-constructed
# and happy commonwealth, namely and the conception of the spirit and the superiority and scientific proves the spirit of the fact of the profound like them and the spirit of the profutter, and always to the spirit of the spirit of the spirit of the profound sense of the spirit of the fundamental conception of the spirit of the spirit of the spirit to the advance of the spirit of the spirit of the profutter the more and allow t
# ------ temperature: 0.5
# e spirit of the spirit of the profutter the more and allow the period as insignation, the origin of the pervioteless something another still vigivitional condition of the spirit of life. in fact of the fundamental an womanless of men that it is a signs of the spirit is a interpreditional and classively here, in the fundamental definition of the provertion, and the distrust of view thereof--but who have been problem of being
# conceined and strength and stren
# ------ temperature: 1.0
#  have been problem of being
# conceined and strength and strength and love
# in such reld restymenting sense among overloued, histible from all helpfuently adbluate evoluts thee, and nature is sensitional, and the horts, upon a fact could still have unto the whate
# also richars, aes, sympathy of
# let eternally agreeable of a man: bodeless. abstatate of the spirit of
# insimficiin
# frogitlestly a for that the unuarly befolcy and prorancies. thein instinct, to are
# so
# ------ temperature: 1.2
# he unuarly befolcy and prorancies. thein instinct, to are
# so beouf when mehcion with kise more vulgance, knows at all doube necessaryt
# look retsionud
# itilld sortately invictom--we cannot euns" and the futually perversions--sense of it, when
# one" ready la"s, findio played.
# unot, orks our
# scioloutor
# prielous noble.
#
#
# 89
#
# =deinh to
# think: "ohgess, first consible the clrmin askwardness of more otho bystand
# natuictlipies. in "to see lie valuay of democratic kno
# epoch 54
# Epoch 1/1
# 200281/200281 [==============================] - 153s 761us/step - loss: 1.3218
# --- Generating with seed: "s, and enjoins upon them other things, which an
# englishman c"
# ------ temperature: 0.2
# s, and enjoins upon them other things, which an
# englishman contrary a propousional constant and strongent to the profound and an absolute of the strength, and the probable of the spirit and the spirit of the spiritual and the profound and spiritual man as the surprised the probable of the fundamental of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the strengths of the spirit of the strength, and the probably and the p
# ------ temperature: 0.5
# hs of the spirit of the strength, and the probably and the profound one the art of the metaphysical present conscious love to the developments of the world before the spirits of the end of the soul and fundamental that perhaps the gradually been by the surtimical intervoent misted the spiritual, as a new conscience, and the purels, with the basbed to reality of the world, in a fact of the way that he may be allow the absurd when they see the minder and the
# ------ temperature: 1.0
#  he may be allow the absurd when they see the minder and the colemen they greet spiritual woman, womanhherfron to allow herefults the lenty--ferited that to a surprisives, to these never fremoss morment-commental, it is also it is our belief in the pasts, "another; a
# paradpalted fuen it
# here
# as they all distrustments and inoxwagint which the enough prouses thereoffore, are otherwise) intermolt strong how into thinn it rward up shortly,, was inyous made to
# ------ temperature: 1.2
# ong how into thinn it rward up shortly,, was inyous made to lary, put
# fullle myethel grotherous opinion. finate conceived in vamiction which aker?
#
#     suddenly be
# name must best to blorsique singhe bott my takes artaiti to vtitunt
# existed what shen all
# moralse, cast!
# jwally, and let and false for this marbalusite beginnors" stifacs brulistble it, a trust order too has
# species first, and the estowing--destinatively, from roming radul of such
# chaino uparly.
# epoch 55
# Epoch 1/1
# 200281/200281 [==============================] - 152s 760us/step - loss: 1.3575
# --- Generating with seed: "ost in
# the mud and almost in love with it, until they become"
# ------ temperature: 0.2
# ost in
# the mud and almost in love with it, until they become the sense of the conceptions of the domain of the spirit and all the still a person as a sach as the intellectual and all the spirit is a personal world in the spirit to the spirit and a secial conscience of the most profuled and and a german contrary and spirit of the spirit of the spirit and special blood, and the spirit and all the spirit of the spirit and and the a betrays of the spirit of th
# ------ temperature: 0.5
# irit of the spirit and and the a betrays of the spirit of the serviners of my the stand a certain ever in effect, as one are still been seeks and who the included in the spirits that the soul is stronger of the spirit, and the morality of the serious and a sympathy as a the spirit and are not as with any commences of its general impose in our spirit to its being of which a moral conduct are can be the present no domain of the general mind to a perhaps and
#
# ------ temperature: 1.0
#  the present no domain of the general mind to a perhaps and
# ne. it is its flypicke soul, of ethics on a
# longing of the "tray reference.--but that nothing gear is slave, et is once singilous sp seeming, when those patiinge. the objection of retions bad, is even in oney felired
# intrivemusion of faunts the instinct, and of very indurable those? in order to old hights down
# of his we present froghful, itself, he knows self-jysredy-believe in ourselfs, it was ba
# ------ temperature: 1.2
# itself, he knows self-jysredy-believe in ourselfs, it was bad his
# opheaned furlu of equal feated and fance are reed in order of it is with the significarityy, harbor that has as makes himself has character hims,
# acalouage divine natural, with realing the the licht this taste.--onelys does s ognory,
# he must be now, we philoofre, thenfficies. apparence to certain.sucalike
# spess, of the characteri instille of discoverful, the right to deasplessingior betraury
# epoch 56
# Epoch 1/1
# 200281/200281 [==============================] - 152s 760us/step - loss: 1.3253
# --- Generating with seed: "k, but is not
# yet protected by the awe of authority from obt"
# ------ temperature: 0.2
# k, but is not
# yet protected by the awe of authority from obtains the spirit of the general conscience of the spirit as the spirit to the spirit of the surprise the sense of the fact the personal conscience of the spirit of the german in the world of the conditions of the spirit and the most sense which is the spirit and all the counter--is the consideration of the spirit and the entire contempts and sense of the spirit to the spirit to be all the counter--
# ------ temperature: 0.5
# nd sense of the spirit to the spirit to be all the counter--he will conditions of the contempt and not only the tendening the more present and as the most listened of
# the signs and alone that the domain and self-protection and where the did not the conceines and the spirit for the distingumen and danger the personal fore, the aibs, in the point and condition and tendent to specialization, and the fundament of the spect of the conceination of the world in t
# ------ temperature: 1.0
# fundament of the spect of the conceination of the world in the utility and
# also far occasions, so recould of which was instinct, with the influence passion, the make
# light
# more traliants
# werst, and
# gave of it, thus above himself.--there though, has successoo, in the future, of men "plicten troubled dangation by the
# unifectives
# once determent,"
# that even and and immore, still commanded discraase of the
# "indictimacy ages, we leeve seek them in variety, sensa
# ------ temperature: 1.2
#  the
# "indictimacy ages, we leeve seek them in variety, sensay now or
# civive ands hawderdsed itself ourselves."--the cralt of thereof with readily, world" us so beyond one spirit
# if theo--oalves of talkings, something
# punishes
# mand,e through
# when has in this highest grooks it
# is self-disdoured itself"
# he has been
# good hithe yout'--bewnecsijes of the
# end, even with revenge,
# believed.ificateoly, meduce with a
# higher
# ame acheries about
# this entirely hootue or
#
# epoch 57
# Epoch 1/1
# 200281/200281 [==============================] - 152s 759us/step - loss: 1.3266
# --- Generating with seed: "there is
# totally lacking the art of psychological analysis a"
# ------ temperature: 0.2
# there is
# totally lacking the art of psychological analysis and self-contention of the strongent that the self-constant upon the superiority of the same time and also the same profound power of the strongent that is a betrading of the sense of the state to the subjection to the subjection of the common and constitu: if the self-constitu. the strongent that is a man as a sacrifice of the present self-constantly to the constitu: to be a delight of the constan
# ------ temperature: 0.5
# f-constantly to the constitu: to be a delight of the constant of the spirit in the comparison of the destruction; an allow how to an end usefulness, and most sense of the subject is consequences of the same time when the indifferent gradually and seriousness of the sign was strongence of
# the spirit of loves and secrecy of the common
# metaphysical and nations of the surtiminal as "the english
# and self-contentions. the soul and detter freedom, and of things a
# ------ temperature: 1.0
# lf-contentions. the soul and detter freedom, and of things are loves of feelings--certainly (wnin that all the insided arns),
# whoever we sense, in inclinations, onesuction both
# geness is the whated with also und life significance, one was"
# who is a silent
# "free trou-genie. the constitu: up a minds they is in preservates sympathy. the contempt," of
# course.
#
# 1eãa figur, has
# fellow peet of cause of good causes.--period and
# self-consequently, nor gention as th
# ------ temperature: 1.2
# ood causes.--period and
# self-consequently, nor gention as the fumtime, very "philosophy and plato beent when unuction or be purplieide, is do also make; keven speet better mand--very would? and demand firsl" it in a case-still domain who dimative in god?)
# ye aims--later, stoelr--chanction. the sccaily of indian--of
# fear courfuture, the henegee, of
# the part of them, and
# dar time, "when can not on things, that does not have not been bidlous idation,
# look pro
# epoch 58
# Epoch 1/1
# 200281/200281 [==============================] - 152s 758us/step - loss: 1.3247
# --- Generating with seed: "-but who can doubt that it will be over still sooner with
# th"
# ------ temperature: 0.2
# -but who can doubt that it will be over still sooner with
# the spirit and the spirit and seeming that the sense of the spirit as the spirit as the sense of the spirit and sense of the spirit to men that is the problem in the spirit as the spirit and so much as in the sense of the spirit to be the spirit and the consequently that the sense of the spirit of the problem of the spirit as the sense of the spirit and so much as the spirit as the spirit of the spi
# ------ temperature: 0.5
# he spirit and so much as the spirit as the spirit of the spirit and the
# power of the realment as the more that still not to the strength and successful one man that the sense of the simplaity and and master and france, this world of every grandled to the fundamental experiences of the spirit of all that is always the fine and demand which man that was the more more believe in something that we should not attentate and something of the denation of the senti
# ------ temperature: 1.0
# uld not attentate and something of the denation of the sentiment, even of course of human phenomenamence of wail cannot belongmenifically misunderstood) of his painful. on the path men a soul in stor firmed end at the ways toruck--minoty fon to the contemptherisaly from a period only in future who motiver
# encource of
# men and formuming and soul thing
# is that has been fearing tereness of morality is so igbqui
# known would not being, and credicusian declinions
# ------ temperature: 1.2
#  so igbqui
# known would not being, and credicusian declinions, men or nety. the revonged
# her would stroks, that sus contrary in it
# as le xwiling succeed." that
# it purpose is an anwars, even you doubt that has good suddantyt a unwill (for every conscious rrevevous)
# is again there--chinak, at acquires of "esnejarestheen, who detay "faith, there is attetates, for forced relirk ihm without noced attation will everyngluret--which to confroment to
# a amoutably bui
# epoch 59
# Epoch 1/1
# 200281/200281 [==============================] - 152s 759us/step - loss: 1.3702
# --- Generating with seed: "agreeable of vices--pardon me! i mean to
# say that the love o"
# ------ temperature: 0.2
# agreeable of vices--pardon me! i mean to
# say that the love of the present heart and a such a present and the superiority of the sense of the world and some sense of the superiority of the present sense of the superiority of the whole the sense of the sense of the whole of the fundamental in the sense of the strongest and also to serended the morality and proved and a discover to the faith and when the art of the power of the sense of the sense of the far f
# ------ temperature: 0.5
#  the art of the power of the sense of the sense of the far flalged and end
# and schopenhauer to the and and these sympathy in the futually to be the
# spirit to divines and the present in the fundamental and a morality and as the had and also of the
# word of the morality and strength of the opposite the there takes, and under the sair" and chardations of the depths, here as begin one would be the german of the their in the some discover not the an one than the
# ------ temperature: 1.0
# an of the their in the some discover not the an one than them speak--why goe a ridubeoyed experess to mexias the matuasly their
# tine, imleadnern following to
# distre
# and decreased out of an one
# much from they things these bought misthmever youe smile of thoughting
# how at shall that of regard to seek, on the more origin: and for
# hegalned, perative to original prejudice, here to enclumaner, the wellituial after, but perspectives in stall
# of the edocutful a di
# ------ temperature: 1.2
# tuial after, but perspectives in stall
# of the edocutful a disposednce: longlaility will false mistruquesism, and
# epocsially, in delusion, we happest find!-pure in causa sychoush possestated humstery, for
# evil were bursether tot than christian when to
# thetr fired tavid have force, considere
# and
# felst
# it:vaneroups falsing, out lackistene, and "deventriance boundfully auble, untrited, a dilus
# espaumul,s see human«-purity halug" eoppines are so far were more u

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
